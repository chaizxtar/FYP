# %%
from Preprocessor import Preprocessor

# %%
video = 'Dataset/video/WILLIAM - BUSINESS ANALYST - INDONESIA/VIDEO/Question 1.mp4'

# %%
preprocess = Preprocessor()
preprocess.load_video(video)
preprocess.show_images(10)
# Out:
# Video fully processed. All frames extracted.
# 313

# %%
preprocess.convert_to_grayscale()
preprocess.show_images(10)

# %%
preprocess.detect_and_crop_face()
preprocess.show_images(10)
print(preprocess.get_data()[0].shape)
data = preprocess.get_data()
print(len(data))
# Out:
# (300, 300)
# 313

# %%
preprocess.resize_image((48,48))
preprocess.show_images(10)

# %%
preprocess.histogram_equalization()
preprocess.show_images(10)
